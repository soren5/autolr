# %%
from sge.parameters import load_parameters, params
from evaluators.adaptive_optimizer_evaluator_imagenet import train_model_tensorflow_imagenet
load_parameters("parameters/imagenet.yml")
phen = "alpha_func, beta_func, sigma_func, grad_func, momentum_const, variance_const, layer_wise_lr_trust_const = lambda momentum, variance, layer_wise_lr, strides, kernel_size, filters, dilation_rate, units, pool_size, layer_count, layer_num, shape, alpha, grad: None, lambda momentum, variance, layer_wise_lr, strides, kernel_size, filters, dilation_rate, units, pool_size, layer_count, layer_num, shape, alpha, beta, grad: None, lambda momentum, variance, layer_wise_lr, strides, kernel_size, filters, dilation_rate, units, pool_size, layer_count, layer_num, shape, alpha, beta, sigma, grad: None, lambda momentum, variance, layer_wise_lr, strides, kernel_size, filters, dilation_rate, units, pool_size, layer_count, layer_num, shape, alpha, beta, sigma, grad: tf.math.add(strides, tf.math.add(kernel_size, tf.math.add(filters, tf.math.add(dilation_rate, tf.math.add(units, pool_size))))), 0.9"
#phen = "alpha_func, beta_func, sigma_func, grad_func = lambda has_strides, strides, has_kernel_size, kernel_size, has_filters, filters, has_dilation_rate, dilation_rate, has_units, units, has_pool_size, pool_size, layer_count, layer_num, shape, alpha, grad: tf.math.divide_no_nan(tf.math.pow(tf.math.add(tf.math.divide_no_nan(tf.math.multiply(tf.math.multiply(tf.constant(9.80911458e-01, shape=shape, dtype=tf.float32), tf.constant(9.99847452e-01, shape=shape, dtype=tf.float32)), tf.math.add(tf.math.add(tf.math.multiply(has_dilation_rate, dilation_rate), tf.math.multiply(has_dilation_rate, dilation_rate)), tf.constant(8.92947854e-01, shape=shape, dtype=tf.float32))), tf.math.multiply(has_units, units)), alpha), tf.math.multiply(has_kernel_size, kernel_size)), grad), lambda has_strides, strides, has_kernel_size, kernel_size, has_filters, filters, has_dilation_rate, dilation_rate, has_units, units, has_pool_size, pool_size, layer_count, layer_num, shape, alpha, beta, grad: tf.math.multiply(grad, tf.math.add(tf.math.multiply(grad, grad), tf.math.multiply(grad, tf.math.multiply(has_dilation_rate, dilation_rate)))), lambda has_strides, strides, has_kernel_size, kernel_size, has_filters, filters, has_dilation_rate, dilation_rate, has_units, units, has_pool_size, pool_size, layer_count, layer_num, shape, alpha, beta, sigma, grad: tf.math.subtract(tf.math.multiply(has_kernel_size, kernel_size), tf.math.divide_no_nan(tf.math.multiply(grad, tf.constant(2.57431039e-03, shape=shape, dtype=tf.float32)), layer_num)), lambda has_strides, strides, has_kernel_size, kernel_size, has_filters, filters, has_dilation_rate, dilation_rate, has_units, units, has_pool_size, pool_size, layer_count, layer_num, shape, alpha, beta, sigma, grad: sigma"
#opt = CustomOptimizerArchV2(phen=phen)
phen_with_layer_var = "alpha_func, beta_func, sigma_func, grad_func = lambda has_strides, strides, has_kernel_size, kernel_size, has_filters, filters, has_dilation_rate, dilation_rate, has_units, units, has_pool_size, pool_size, layer_count, layer_num, shape, alpha, grad: add(grad, multiply(alpha, add(constant(9.98279874e-01), multiply(has_dilation_rate, dilation_rate)))), lambda has_strides, strides, has_kernel_size, kernel_size, has_filters, filters, has_dilation_rate, dilation_rate, has_units, units, has_pool_size, pool_size, layer_count, layer_num, shape, alpha, beta, grad: multiply(grad, add(divide_no_nan(constant(2.79614739e-04), pow(layer_num, multiply(multiply(grad, multiply(multiply(grad, square(constant(9.99771521e-01))), add(layer_count, grad))), sqrt(constant(5.12469082e-04))))), add(multiply(grad, multiply(multiply(subtract(pow(add(divide_no_nan(pow(layer_count, subtract(grad, multiply(has_strides, strides))), grad), multiply(has_units, units)), square(layer_num)), grad), beta), alpha)), multiply(grad, multiply(add(divide_no_nan(negative(multiply(grad, multiply(has_filters, filters))), grad), pow(constant(1.01848815e-04), add(grad, beta))), multiply(has_pool_size, pool_size)))))), lambda has_strides, strides, has_kernel_size, kernel_size, has_filters, filters, has_dilation_rate, dilation_rate, has_units, units, has_pool_size, pool_size, layer_count, layer_num, shape, alpha, beta, sigma, grad: square(add(constant(8.19823407e-01), divide_no_nan(pow(divide_no_nan(sigma, layer_num), multiply(grad, layer_num)), multiply(has_kernel_size, kernel_size)))), lambda has_strides, strides, has_kernel_size, kernel_size, has_filters, filters, has_dilation_rate, dilation_rate, has_units, units, has_pool_size, pool_size, layer_count, layer_num, shape, alpha, beta, sigma, grad: negative(alpha)"
phen_without_layer_var = "alpha_func, beta_func, sigma_func, grad_func = lambda has_strides, strides, has_kernel_size, kernel_size, has_filters, filters, has_dilation_rate, dilation_rate, has_units, units, has_pool_size, pool_size, layer_count, layer_num, shape, alpha, grad: add(grad, multiply(alpha, constant(9.98279874e-01))), lambda has_strides, strides, has_kernel_size, kernel_size, has_filters, filters, has_dilation_rate, dilation_rate, has_units, units, has_pool_size, pool_size, layer_count, layer_num, shape, alpha, beta, grad: multiply(grad, add(divide_no_nan(constant(2.79614739e-04), pow(layer_num, multiply(multiply(grad, multiply(multiply(grad, square(constant(9.99771521e-01))), add(layer_count, grad))), sqrt(constant(5.12469082e-04))))), add(multiply(grad, multiply(multiply(subtract(pow(add(divide_no_nan(pow(layer_count, subtract(grad, multiply(has_strides, strides))), grad), multiply(has_units, units)), square(layer_num)), grad), beta), alpha)), multiply(grad, multiply(add(divide_no_nan(negative(multiply(grad, multiply(has_filters, filters))), grad), pow(constant(1.01848815e-04), add(grad, beta))), multiply(has_pool_size, pool_size)))))), lambda has_strides, strides, has_kernel_size, kernel_size, has_filters, filters, has_dilation_rate, dilation_rate, has_units, units, has_pool_size, pool_size, layer_count, layer_num, shape, alpha, beta, sigma, grad: square(add(constant(8.19823407e-01), divide_no_nan(pow(divide_no_nan(sigma, layer_num), multiply(grad, layer_num)), multiply(has_kernel_size, kernel_size)))), lambda has_strides, strides, has_kernel_size, kernel_size, has_filters, filters, has_dilation_rate, dilation_rate, has_units, units, has_pool_size, pool_size, layer_count, layer_num, shape, alpha, beta, sigma, grad: negative(alpha)"
params["PATIENCE"] = 12

train_model_tensorflow_imagenet([phen, params])
# Out:
# Metal device set to: Apple M4
#
# systemMemory: 24.00 GB
# maxCacheSize: 8.00 GB
#
# 1 Physical GPUs, 1 Logical GPUs
# using  parameters/imagenet.yml for parameters
# 2025-10-06 13:31:13.575271: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2025-10-06 13:31:13.575584: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# 2025-10-06 13:31:13.577161: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# ...
